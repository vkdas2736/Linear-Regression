# %%
import pandas  as pd

# %%
import numpy as np

# %%
dfins = pd.read_csv(r'C:\Users\ajjup\OneDrive\Desktop\DATASETS\Linear Regression\Big dataset\insurance.csv')

# %%
dfins
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
dfins.isna()
# Out:
#         age  gender    bmi  children  smoker  region  charges
# 0     False   False  False     False   False   False    False
# 1     False   False  False     False   False   False    False
# 2     False   False  False     False   False   False    False
# 3     False   False  False     False   False   False    False
# 4     False   False  False     False   False   False    False
# ...     ...     ...    ...       ...     ...     ...      ...
# 1333  False   False  False     False   False   False    False
# 1334  False   False  False     False   False   False    False
# 1335  False   False  False     False   False   False    False
# 1336  False   False  False     False   False   False    False
# 1337  False   False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
dfins.isna().sum()
# Out:
# age         0
# gender      0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
dfins.dtypes
# Out:
# age           int64
# gender       object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
dfins.dtypes == object
# Out:
# age         False
# gender       True
# bmi         False
# children    False
# smoker       True
# region       True
# charges     False
# dtype: bool

# %%
dfins.dtypes[dfins.dtypes == object].index
# Out:
# Index(['gender', 'smoker', 'region'], dtype='object')

# %%
dfins[['gender', 'smoker', 'region']]
# Out:
#       gender smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1338 rows x 3 columns]

# %%
dfins["region"]
# Out:
# 0       southwest
# 1       southeast
# 2       southeast
# 3       northwest
# 4       northwest
#           ...
# 1333    northwest
# 1334    northeast
# 1335    southeast
# 1336    southwest
# 1337    northwest
# Name: region, Length: 1338, dtype: object

# %%
dfins["region"].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
dfcat = dfins[['gender', 'smoker', 'region']]

# %%
dfcat
# Out:
#       gender smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1338 rows x 3 columns]

# %%
dfcat = pd.get_dummies(dfcat, drop_first=True)

# %%
dfcat
# Out:
#       gender_male  smoker_yes  region_northwest  region_southeast  \
# 0               0           1                 0                 0
# 1               1           0                 0                 1
# 2               1           0                 0                 1
# 3               1           0                 1                 0
# 4               1           0                 1                 0
# ...           ...         ...               ...               ...
# 1333            1           0                 1                 0
# 1334            0           0                 0                 0
# 1335            0           0                 0                 1
# 1336            0           0                 0                 0
# 1337            0           1                 1                 0
#
#       region_southwest
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# ...

# %%
dfins
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
dfins = pd.concat([dfins, dfcat], axis = 1)

# %%
dfins
# Out:
#       age  gender     bmi  children smoker     region      charges  \
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
#       gender_male  smoker_yes  region_northwest  region_southeast  \
# 0               0           1                 0                 0
# ...

# %%
dfins  = dfins.drop(['gender', 'smoker', 'region'], axis = 1)

# %%
dfins
# Out:
#       age     bmi  children      charges  gender_male  smoker_yes  \
# 0      19  27.900         0  16884.92400            0           1
# 1      18  33.770         1   1725.55230            1           0
# 2      28  33.000         3   4449.46200            1           0
# 3      33  22.705         0  21984.47061            1           0
# 4      32  28.880         0   3866.85520            1           0
# ...   ...     ...       ...          ...          ...         ...
# 1333   50  30.970         3  10600.54830            1           0
# 1334   18  31.920         0   2205.98080            0           0
# 1335   18  36.850         0   1629.83350            0           0
# 1336   21  25.800         0   2007.94500            0           0
# 1337   61  29.070         0  29141.36030            0           1
#
#       region_northwest  region_southeast  region_southwest
# 0                    0                 0                 1
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(dfins['children'], rwidth=0.90)
# Out:
# (array([574.,   0., 324.,   0., 240.,   0., 157.,   0.,  25.,  18.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

# %%
sns.countplot(x = 'children', data =  dfins)
# Out:
# <AxesSubplot:xlabel='children', ylabel='count'>

# %%
sns.countplot(x= 'gender_male', data = dfins)
# Out:
# <AxesSubplot:xlabel='gender_male', ylabel='count'>

# %%
plt.hist(dfins['bmi'], rwidth=0.80)
plt.show()

# %%
plt.hist(dfins['bmi'], bins = 35,rwidth=0.90)
plt.show()

# %%
dfins['bmi'].skew()
# Out:
# 0.2840471105987448

# %%
sns.distplot(dfins["bmi"])
# Out:
# c:\users\ajjup\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='bmi', ylabel='Density'>

# %%
dfins
# Out:
#       age     bmi  children      charges  gender_male  smoker_yes  \
# 0      19  27.900         0  16884.92400            0           1
# 1      18  33.770         1   1725.55230            1           0
# 2      28  33.000         3   4449.46200            1           0
# 3      33  22.705         0  21984.47061            1           0
# 4      32  28.880         0   3866.85520            1           0
# ...   ...     ...       ...          ...          ...         ...
# 1333   50  30.970         3  10600.54830            1           0
# 1334   18  31.920         0   2205.98080            0           0
# 1335   18  36.850         0   1629.83350            0           0
# 1336   21  25.800         0   2007.94500            0           0
# 1337   61  29.070         0  29141.36030            0           1
#
#       region_northwest  region_southeast  region_southwest
# 0                    0                 0                 1
# ...

# %%
X = dfins.drop('charges', axis= 1)

# %%
X
# Out:
#       age     bmi  children  gender_male  smoker_yes  region_northwest  \
# 0      19  27.900         0            0           1                 0
# 1      18  33.770         1            1           0                 0
# 2      28  33.000         3            1           0                 0
# 3      33  22.705         0            1           0                 1
# 4      32  28.880         0            1           0                 1
# ...   ...     ...       ...          ...         ...               ...
# 1333   50  30.970         3            1           0                 1
# 1334   18  31.920         0            0           0                 0
# 1335   18  36.850         0            0           0                 0
# 1336   21  25.800         0            0           0                 0
# 1337   61  29.070         0            0           1                 1
#
#       region_southeast  region_southwest
# 0                    0                 1
# ...

# %%
X.shape
# Out:
# (1338, 8)

# %%
y = dfins['charges']

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,  Xtest, ytrain, ytest = train_test_split(X,y,test_size=0.20, random_state=42)

# %%
Xtrain.shape, Xtest.shape, X.shape
# Out:
# ((1070, 8), (268, 8), (1338, 8))

# %%
Xtrain.head(10)
# Out:
#       age     bmi  children  gender_male  smoker_yes  region_northwest  \
# 560    46  19.950         2            0           0                 1
# 1285   47  24.320         0            0           0                 0
# 1142   52  24.860         0            0           0                 0
# 969    39  34.320         5            0           0                 0
# 486    54  21.470         3            0           0                 1
# 170    63  41.470         0            1           0                 0
# 277    22  24.300         0            0           0                 0
# 1033   18  21.565         0            1           1                 0
# 209    40  41.230         1            1           0                 0
# 947    37  34.200         1            1           1                 0
#
#       region_southeast  region_southwest
# 560                  0                 0
# 1285                 0                 0
# 1142                 1                 0
# ...

# %% [markdown]
# ### MODEL BUILDING

# %%
from sklearn.linear_model import LinearRegression

# %%
lrmodel = LinearRegression()

# %%
lrmodel
# Out:
# LinearRegression()

# %%
lrmodel.fit(Xtrain, ytrain)
# Out:
# LinearRegression()

# %%
lrmodel.coef_
# Out:
# array([ 2.56975706e+02,  3.37092552e+02,  4.25278784e+02, -1.85916916e+01,
#         2.36511289e+04, -3.70677326e+02, -6.57864297e+02, -8.09799354e+02])

# %%
lrmodel.intercept_
# Out:
# -11931.219050326692

# %%
lrmodel.score(Xtest,ytest)
# Out:
# 0.7835929767120723

# %%
lrmodel.predict([[25,42,2,1,0,0,1,0]])
# Out:
# c:\users\ajjup\appdata\local\programs\python\python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([8825.16235614])

# %%
Xtrain
# Out:
#       age     bmi  children  gender_male  smoker_yes  region_northwest  \
# 560    46  19.950         2            0           0                 1
# 1285   47  24.320         0            0           0                 0
# 1142   52  24.860         0            0           0                 0
# 969    39  34.320         5            0           0                 0
# 486    54  21.470         3            0           0                 1
# ...   ...     ...       ...          ...         ...               ...
# 1095   18  31.350         4            0           0                 0
# 1130   39  23.870         5            0           0                 0
# 1294   58  25.175         0            1           0                 0
# 860    37  47.600         2            0           1                 0
# 1126   55  29.900         0            1           0                 0
#
#       region_southeast  region_southwest
# 560                  0                 0
# ...

# %%
plt.scatter(Xtrain['age'], ytrain)
